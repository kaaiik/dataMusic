# %%
import pandas as pd
import pylab as plt
import seaborn as sns

# %%
def check_nan(df):
    
    nan_cols=df.isna().mean() * 100
    
    display(f'N nan cols: {len(nan_cols[nan_cols>0])}')
    display(nan_cols[nan_cols>0])
    
    plt.figure(figsize=(10, 6))

    sns.heatmap(df.isna(),  # mapa de calor
                yticklabels=False,
                cmap='viridis',
                cbar=False)
    
    plt.show();

# %%
df = pd.read_csv('../data/GDP_annual_growth.csv')
df = df[(df['Country Code'] == 'USA') | 
    (df['Country Code'] == 'ESP') |
    (df['Country Code'] == 'CHN') |
    (df['Country Name'] == 'United Kingdom') |
    (df['Country Code'] == 'AUS') |
    (df['Country Name'] == 'South Africa') |
    (df['Country Code'] == 'VEN') |
    (df['Country Code'] == 'ARG')]

df = df.drop(['Indicator Code', '2020', 'Unnamed: 65'], axis=1)

df = df.drop(['1960', '1961'], axis=1)

df.head()
# Out:
#       Country Name Country Code     Indicator Name          1962  \
# 7        Argentina          ARG  GDP (current US$)  2.445060e+10
# 11       Australia          AUS  GDP (current US$)  1.989249e+10
# 38           China          CHN  GDP (current US$)  4.720936e+10
# 68           Spain          ESP  GDP (current US$)  1.613855e+10
# 79  United Kingdom          GBR  GDP (current US$)  8.124756e+10
#
#             1963          1964          1965          1966          1967  \
# 7   1.827212e+10  2.560525e+10  2.834471e+10  2.863047e+10  2.425667e+10
# 11  2.150745e+10  2.376414e+10  2.593684e+10  2.726845e+10  3.039758e+10
# 38  5.070680e+10  5.970834e+10  7.043627e+10  7.672029e+10  7.288163e+10
# 68  1.907491e+10  2.134384e+10  2.475696e+10  2.872106e+10  3.164712e+10
# 79  8.656196e+10  9.440756e+10  1.018248e+11  1.085728e+11  1.131169e+11
#
#             1968  ...          2010          2011          2012          2013  \
# ...

# %% [markdown]
# # Consumo de alcohol

# %%
df2 = pd.read_csv('../data/archive(6)/tobacco_alcohol_drug_german_teens_allGender.csv')
df2
# Out:
#                    Unnamed: 0  male_female  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                         NaN       1973.0      1976.0      1979.0       1982
# 1  frequent_occasional_smoker         58.0        54.0        44.0         40
# 2                        beer         48.0        48.0        38.0         34
# 3              wine_sparkWine         24.0        24.0        17.0         15
# 4                 hard_liquor         20.0        16.0         9.0          7
# 5                mixed_liquor          NaN         NaN         NaN          .
# 6           alcopop_with_beer          NaN         NaN         NaN        NaN
# 7         alcopop_with_liquor          NaN         NaN         NaN        NaN
# 8    experience_illegal_drugs         19.0        15.0        16.0         17
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0      1986.0      1989.0      1993.0      1997.0      2001.0  ...
# ...

# %%
df2.iloc[:1] = df2.iloc[:1].fillna('Type')
df2
# Out:
#                    Unnamed: 0  male_female  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                        Type       1973.0      1976.0      1979.0       1982
# 1  frequent_occasional_smoker         58.0        54.0        44.0         40
# 2                        beer         48.0        48.0        38.0         34
# 3              wine_sparkWine         24.0        24.0        17.0         15
# 4                 hard_liquor         20.0        16.0         9.0          7
# 5                mixed_liquor          NaN         NaN         NaN          .
# 6           alcopop_with_beer          NaN         NaN         NaN        NaN
# 7         alcopop_with_liquor          NaN         NaN         NaN        NaN
# 8    experience_illegal_drugs         19.0        15.0        16.0         17
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0      1986.0      1989.0      1993.0      1997.0      2001.0  ...
# ...

# %%
cols=list(df2.iloc[:1].values)
df2.columns = cols
df2
# Out:
#                          Type  1973.0  1976.0  1979.0   1982  1986.0  1989.0  \
# 0                        Type  1973.0  1976.0  1979.0   1982  1986.0  1989.0
# 1  frequent_occasional_smoker    58.0    54.0    44.0     40    45.0    43.0
# 2                        beer    48.0    48.0    38.0     34    39.0    37.0
# 3              wine_sparkWine    24.0    24.0    17.0     15    14.0    14.0
# 4                 hard_liquor    20.0    16.0     9.0      7     5.0     5.0
# 5                mixed_liquor     NaN     NaN     NaN      .    10.0     9.0
# 6           alcopop_with_beer     NaN     NaN     NaN    NaN     NaN     NaN
# 7         alcopop_with_liquor     NaN     NaN     NaN    NaN     NaN     NaN
# 8    experience_illegal_drugs    19.0    15.0    16.0     17    17.0    17.0
#
#    1993.0  1997.0  2001.0  ...  1982.0  1986.0  1989.0  1993.0  1997.0  \
# 0  1993.0  1997.0  2001.0  ...  1982.0  1986.0  1989.0  1993.0  1997.0
# ...

# %%
df2 = df2.drop(0, axis=0)
df2
# Out:
#                          Type 1973.0 1976.0 1979.0  1982 1986.0 1989.0 1993.0  \
# 1  frequent_occasional_smoker   58.0   54.0   44.0    40   45.0   43.0   37.0
# 2                        beer   48.0   48.0   38.0    34   39.0   37.0   31.0
# 3              wine_sparkWine   24.0   24.0   17.0    15   14.0   14.0   11.0
# 4                 hard_liquor   20.0   16.0    9.0     7    5.0    5.0    7.0
# 5                mixed_liquor    NaN    NaN    NaN     .   10.0    9.0   10.0
# 6           alcopop_with_beer    NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 7         alcopop_with_liquor    NaN    NaN    NaN   NaN    NaN    NaN    NaN
# 8    experience_illegal_drugs   19.0   15.0   16.0    17   17.0   17.0   18.0
#
#   1997.0 2001.0  ... 1982.0 1986.0 1989.0 1993.0 1997.0 2001.0 2004 2008  \
# 1   41.0   37.0  ...   38.0   44.0   40.0   34.0   40.0   36.0   35   33
# 2   26.0   22.0  ...   21.0   20.0   20.0   11.0   11.0   10.0    8    9
# ...
